# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns 
import warnings
warnings.filterwarnings("ignore")

# %%
train_set=pd.read_csv("train_set.csv")

# %%
train_set
# Out:
#      Pregnancies   Glucose  BloodPressure  SkinThickness   Insulin       BMI  \
# 0      -0.844885  0.097192       0.253036       0.969998 -0.692891 -0.532119
# 1      -0.844885 -0.810425       0.666618       0.279989  0.870031  0.381700
# 2      -1.141852 -0.841722       0.046245       0.405445  0.305642  1.460513
# 3       0.936914  1.975021       0.770014       0.781814 -0.692891  0.445159
# 4      -1.141852 -1.498962       0.160438      -1.288212 -0.692891 -1.382478
# ..           ...       ...            ...            ...       ...       ...
# 777    -1.141852  0.351643      -0.227966       0.318145  0.823410  0.025484
# 778     0.046014  1.130536       0.462907      -1.288212 -0.692891  0.112901
# 779    -1.141852  0.408155       0.189753       1.691101  0.396925  0.026834
# 780    -0.250952 -1.048989       0.571269       0.641896 -0.225214  0.204087
# 781     0.639947  0.861192       0.475678      -1.288212 -0.692891 -0.378445
#
#      DiabetesPedigreeFunction       Age  Outcome
# 0                   -1.123111 -0.275760        0
# 1                   -0.721435  0.830381        1
# 2                   -0.377141 -1.041549        0
# 3                   -0.352980  0.660206        1
# 4                   -0.392242 -0.701198        0
# ..                        ...       ...      ...
# 777                  0.002957 -0.841769        1
# 778                  0.976018 -0.200808        1
# 779                 -0.262948 -0.628837        1
# 780                 -0.289093 -0.570256        1
# 781                 -0.887541  1.425995        1
#
# [782 rows x 9 columns]

# %%
test_set=pd.read_csv("test_set.csv")

# %%
test_set
# Out:
#      Pregnancies   Glucose  BloodPressure  SkinThickness   Insulin       BMI  \
# 0      -0.547919 -1.029505       0.253036      -0.096379 -0.232697 -0.379816
# 1      -0.547919  0.253678       0.770014      -1.288212 -0.692891 -0.506735
# 2      -1.141852 -0.591345       0.459827       1.220910  0.088570  0.318240
# 3      -1.141852  0.065895       0.149641      -1.288212 -0.692891  0.546695
# 4      -0.844885  0.723135       0.666618       1.597279  0.870031  1.790503
# ..           ...       ...            ...            ...       ...       ...
# 149    -0.547919 -0.466156      -0.677523       0.405445  0.739787 -0.379816
# 150    -0.547919 -1.185991      -0.160546       0.154533 -0.258746  0.026326
# 151    -1.141852  0.347569       0.459827      -1.288212 -0.692891  0.051710
# 152     0.342981  0.504055       0.160438      -1.288212 -0.692891  2.133185
# 153    -0.844885 -1.498962      -0.987710      -0.660932 -0.692891 -1.141331
#
#      DiabetesPedigreeFunction       Age  Outcome
# 0                   -0.733515 -0.956462        0
# 1                   -0.567409 -0.531023        0
# 2                   -0.706334 -0.786286        0
# 3                   -0.645932  1.596171        1
# 4                   -0.413383  1.085644        1
# ..                        ...       ...      ...
# 149                 -0.138552 -0.956462        0
# 150                  0.075877 -0.956462        0
# 151                 -0.238216 -1.041549        0
# 152                 -0.739555  0.319855        1
# 153                 -0.676133 -1.041549        0
#
# [154 rows x 9 columns]

# %%
x_train=train_set.drop(columns="Outcome")

# %%
y_train=train_set.Outcome

# %%
x_train
# Out:
#      Pregnancies   Glucose  BloodPressure  SkinThickness   Insulin       BMI  \
# 0      -0.844885  0.097192       0.253036       0.969998 -0.692891 -0.532119
# 1      -0.844885 -0.810425       0.666618       0.279989  0.870031  0.381700
# 2      -1.141852 -0.841722       0.046245       0.405445  0.305642  1.460513
# 3       0.936914  1.975021       0.770014       0.781814 -0.692891  0.445159
# 4      -1.141852 -1.498962       0.160438      -1.288212 -0.692891 -1.382478
# ..           ...       ...            ...            ...       ...       ...
# 777    -1.141852  0.351643      -0.227966       0.318145  0.823410  0.025484
# 778     0.046014  1.130536       0.462907      -1.288212 -0.692891  0.112901
# 779    -1.141852  0.408155       0.189753       1.691101  0.396925  0.026834
# 780    -0.250952 -1.048989       0.571269       0.641896 -0.225214  0.204087
# 781     0.639947  0.861192       0.475678      -1.288212 -0.692891 -0.378445
#
#      DiabetesPedigreeFunction       Age
# 0                   -1.123111 -0.275760
# 1                   -0.721435  0.830381
# 2                   -0.377141 -1.041549
# 3                   -0.352980  0.660206
# 4                   -0.392242 -0.701198
# ..                        ...       ...
# 777                  0.002957 -0.841769
# 778                  0.976018 -0.200808
# 779                 -0.262948 -0.628837
# 780                 -0.289093 -0.570256
# 781                 -0.887541  1.425995
#
# [782 rows x 8 columns]

# %%
y_train
# Out:
# 0      0
# 1      1
# 2      0
# 3      1
# 4      0
#       ..
# 777    1
# 778    1
# 779    1
# 780    1
# 781    1
# Name: Outcome, Length: 782, dtype: int64

# %%
x_test=test_set.drop(columns="Outcome")

# %%
x_test
# Out:
#      Pregnancies   Glucose  BloodPressure  SkinThickness   Insulin       BMI  \
# 0      -0.547919 -1.029505       0.253036      -0.096379 -0.232697 -0.379816
# 1      -0.547919  0.253678       0.770014      -1.288212 -0.692891 -0.506735
# 2      -1.141852 -0.591345       0.459827       1.220910  0.088570  0.318240
# 3      -1.141852  0.065895       0.149641      -1.288212 -0.692891  0.546695
# 4      -0.844885  0.723135       0.666618       1.597279  0.870031  1.790503
# ..           ...       ...            ...            ...       ...       ...
# 149    -0.547919 -0.466156      -0.677523       0.405445  0.739787 -0.379816
# 150    -0.547919 -1.185991      -0.160546       0.154533 -0.258746  0.026326
# 151    -1.141852  0.347569       0.459827      -1.288212 -0.692891  0.051710
# 152     0.342981  0.504055       0.160438      -1.288212 -0.692891  2.133185
# 153    -0.844885 -1.498962      -0.987710      -0.660932 -0.692891 -1.141331
#
#      DiabetesPedigreeFunction       Age
# 0                   -0.733515 -0.956462
# 1                   -0.567409 -0.531023
# 2                   -0.706334 -0.786286
# 3                   -0.645932  1.596171
# 4                   -0.413383  1.085644
# ..                        ...       ...
# 149                 -0.138552 -0.956462
# 150                  0.075877 -0.956462
# 151                 -0.238216 -1.041549
# 152                 -0.739555  0.319855
# 153                 -0.676133 -1.041549
#
# [154 rows x 8 columns]

# %%
y_test=test_set.Outcome

# %%
y_test
# Out:
# 0      0
# 1      0
# 2      0
# 3      1
# 4      1
#       ..
# 149    0
# 150    0
# 151    0
# 152    1
# 153    0
# Name: Outcome, Length: 154, dtype: int64

# %%
from sklearn.linear_model import LogisticRegression

# %%
model=LogisticRegression()

# %%
model
# Out:
# LogisticRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_prediction=model.predict(x_test)

# %%
from sklearn.metrics import recall_score , accuracy_score,precision_score,f1_score

# %%
recall_score(y_test,y_prediction)
# Out:
# 0.7333333333333333

# %%
accuracy_score(y_test,y_prediction)
# Out:
# 0.7467532467532467

# %%
precision_score(y_test,y_prediction)
# Out:
# 0.55

# %%
f1_score(y_test,y_prediction)
# Out:
# 0.6285714285714286
